# %%
import time
from datetime import datetime, timedelta

start_time = datetime.now()
print(f"Start time is {start_time}")

time.sleep(30)

end_time = datetime.now()
print(f"End time is {end_time}")

elapsed = end_time - start_time 
print(f"elapsed {elapsed}")
# Out:
# Start time is 2026-01-29 13:25:56.321480
# End time is 2026-01-29 13:26:26.322388
# elapsed 0:00:30.000908

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("XAU_USD Historical Data.csv")

# Show inferred data types
print("Data types for each column:")
print(df.dtypes)

# If you want more detail (like number of unique values, null counts, etc.)
print("\nDetailed info:")
print(df.info())

# Optional: quick summary for each column
summary = pd.DataFrame({
    "dtype": df.dtypes,
    "non_null_count": df.notnull().sum(),
    "unique_values": df.nunique()
})
print("\nColumn summary:")
print(summary)
# Out:
# Data types for each column:
# Date         object
# Price        object
# Open         object
# High         object
# Low          object
# Vol.        float64
# Change %     object
# dtype: object
#
# Detailed info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2607 entries, 0 to 2606
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2607 non-null   object
#  1   Price     2607 non-null   object
#  2   Open      2607 non-null   object
#  3   High      2607 non-null   object
#  4   Low       2607 non-null   object
#  5   Vol.      0 non-null      float64
#  6   Change %  2607 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 142.7+ KB
# None
#
# Column summary:
#             dtype  non_null_count  unique_values
# Date       object            2607           2607
# Price      object            2607           2456
# Open       object            2607           2508
# ...

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("google_trends_gold_keywords_daily_2008_2017.csv")

# Show inferred data types
print("Data types for each column:")
print(df.dtypes)

# If you want more detail (like number of unique values, null counts, etc.)
print("\nDetailed info:")
print(df.info())

# Optional: quick summary for each column
summary = pd.DataFrame({
    "dtype": df.dtypes,
    "non_null_count": df.notnull().sum(),
    "unique_values": df.nunique()
})
print("\nColumn summary:")
print(summary)
# Out:
# Data types for each column:
# date             object
# gold price        int64
# gold forecast     int64
# buy gold          int64
# inflation         int64
# safe haven        int64
# dtype: object
#
# Detailed info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           3653 non-null   object
#  1   gold price     3653 non-null   int64
#  2   gold forecast  3653 non-null   int64
#  3   buy gold       3653 non-null   int64
#  4   inflation      3653 non-null   int64
#  5   safe haven     3653 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 171.4+ KB
# None
#
# Column summary:
#                 dtype  non_null_count  unique_values
# date           object            3653           3653
# gold price      int64            3653             93
# gold forecast   int64            3653             91
# ...

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("gold-dataset-sinha-khandait.csv")

# Show inferred data types
print("Data types for each column:")
print(df.dtypes)

# If you want more detail (like number of unique values, null counts, etc.)
print("\nDetailed info:")
print(df.info())

# Optional: quick summary for each column
summary = pd.DataFrame({
    "dtype": df.dtypes,
    "non_null_count": df.notnull().sum(),
    "unique_values": df.nunique()
})
print("\nColumn summary:")
print(summary)
# Out:
# Data types for each column:
# Dates                       object
# URL                         object
# News                        object
# Price Direction Up           int64
# Price Direction Constant     int64
# Price Direction Down         int64
# Asset Comparision            int64
# Past Information             int64
# Future Information           int64
# Price Sentiment             object
# dtype: object
#
# Detailed info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10570 entries, 0 to 10569
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Dates                     10570 non-null  object
#  1   URL                       10570 non-null  object
#  2   News                      10570 non-null  object
#  3   Price Direction Up        10570 non-null  int64
#  4   Price Direction Constant  10570 non-null  int64
#  5   Price Direction Down      10570 non-null  int64
# ...

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("CBOE Volatility Index Historical Data.csv")

# Show inferred data types
print("Data types for each column:")
print(df.dtypes)

# If you want more detail (like number of unique values, null counts, etc.)
print("\nDetailed info:")
print(df.info())

# Optional: quick summary for each column
summary = pd.DataFrame({
    "dtype": df.dtypes,
    "non_null_count": df.notnull().sum(),
    "unique_values": df.nunique()
})
print("\nColumn summary:")
print(summary)
# Out:
# Data types for each column:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.        float64
# Change %     object
# dtype: object
#
# Detailed info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2518 entries, 0 to 2517
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2518 non-null   object
#  1   Price     2518 non-null   float64
#  2   Open      2518 non-null   float64
#  3   High      2518 non-null   float64
#  4   Low       2518 non-null   float64
#  5   Vol.      0 non-null      float64
#  6   Change %  2518 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 137.8+ KB
# None
#
# Column summary:
#             dtype  non_null_count  unique_values
# Date       object            2518           2518
# Price     float64            2518           1540
# Open      float64            2518           1508
# ...

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("US Dollar Index Futures Historical Data.csv")

# Show inferred data types
print("Data types for each column:")
print(df.dtypes)

# If you want more detail (like number of unique values, null counts, etc.)
print("\nDetailed info:")
print(df.info())

# Optional: quick summary for each column
summary = pd.DataFrame({
    "dtype": df.dtypes,
    "non_null_count": df.notnull().sum(),
    "unique_values": df.nunique()
})
print("\nColumn summary:")
print(summary)
# Out:
# Data types for each column:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.         object
# Change %     object
# dtype: object
#
# Detailed info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2590 entries, 0 to 2589
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2590 non-null   object
#  1   Price     2590 non-null   float64
#  2   Open      2590 non-null   float64
#  3   High      2590 non-null   float64
#  4   Low       2590 non-null   float64
#  5   Vol.      2579 non-null   object
#  6   Change %  2590 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 141.8+ KB
# None
#
# Column summary:
#             dtype  non_null_count  unique_values
# Date       object            2590           2590
# Price     float64            2590           2350
# Open      float64            2590           1917
# ...
